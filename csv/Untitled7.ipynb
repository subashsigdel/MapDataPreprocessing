# %%
import urllib
import requests
import json                 # Used to load data into JSON format
from pprint import pprint   # pretty-print

url = "https://backend.motdev.ran.org.np/about/api/get_team_members/en/?format=json"
response = urllib.request.urlopen(url)
print(response)

# %%
text = response.read()

# %%
json_data = json.loads(text)

pprint(json_data)
# Out:
# {'count': 39,
#  'next': None,
#  'previous': None,
#  'results': [{'created_date': '2021-09-15T08:28:30.562172Z',
#               'description': 'She is a highly passionate Bachelors in Arts of '
#                              'Social Work student who is looking to make a '
#                              'difference in social development works through '
#                              'my critical understanding on Nepal’s vast social '
#                              'cultural differences and strongly support Gender '
#                              'Equality. She is good at expressing her views '
#                              'through her writing and story telling skills. '
#                              'She is leading Communication and Documentation '
#                              'at the moment in Mission Oxygen Team.',
#               'edited_date': '2022-04-25T09:01:57.332808Z',
#               'email': 'matina.maharjan1996@gmail.com',
# ...

# %%
with open("json_file.json", "w") as file:
	json.dump(json_data,file)

# %%
 
import json
import csv
 
 
# Opening JSON file and loading the data
# into the variable data
with open('json_file.json') as json_file:
    data = json.load(json_file)
 
members_data = data['results']
 
# now we will open a file for writing
data_file = open('members.csv', 'w')
 
# create the csv writer object
csv_writer = csv.writer(data_file)
 
# Counter variable used for writing
# headers to the CSV file
count = 0
 
for i in members_data:
    if count == 0:
 
        # Writing headers of CSV file
        header = i.keys()
        csv_writer.writerow(header)
        count += 1
 
    # Writing data of CSV file
    csv_writer.writerow(i.values())
 
data_file.close()
