# %%
import json
import numpy as np
import pandas as pd
import plotly.express as px

# %%
import webbrowser as browser
import plotly.io as pio
pio.renderers.default = 'browser'

# %%
nepali_states = json.load(open("nepal-states.geojson", "r"))

# %%
import geopandas as gpd
earthquake = gpd.read_file('nepal-states.geojson')
print(earthquake)
# Out:
#    Shape_Leng  Shape_Area ADM1_EN ADM1_PCODE ADM1_REF ADM1ALT1EN ADM1ALT2EN  \
# 0   10.602486    2.374642       1       NP01     None       None       None
# 1    9.020607    0.871738       2       NP02     None       None       None
# 2   10.501670    1.857077       3       NP03     None       None       None
# 3   10.783497    2.024264       4       NP04     None       None       None
# 4   12.624719    1.768381       5       NP05     None       None       None
# 5   13.983647    2.852129       6       NP06     None       None       None
# 6    9.830593    1.834355       7       NP07     None       None       None
#
#   ADM0_EN ADM0_PCODE        date     validOn validTo  \
# 0   Nepal         NP  2017-11-15  2019-04-30    None
# 1   Nepal         NP  2017-11-15  2019-04-30    None
# 2   Nepal         NP  2017-11-15  2019-04-30    None
# 3   Nepal         NP  2017-11-15  2019-04-30    None
# 4   Nepal         NP  2017-11-15  2019-04-30    None
# ...

# %%
import geoplot
import geoplot.crs as gcrs

# %%
geoplot.polyplot(earthquake, projection=gcrs.AlbersEqualArea(), edgecolor='darkgrey', facecolor='lightgrey', linewidth=.3,
    figsize=(30, 30))
# Out:
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:228: ShapelyDeprecationWarning:
#
# __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:280: ShapelyDeprecationWarning:
#
# Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:347: ShapelyDeprecationWarning:
#
# __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
